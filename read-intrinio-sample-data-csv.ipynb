# %% [markdown]
# # read-intrinio-sample-data.csv
#
# Read in Intrinio sample data

# %%
import pandas as pd

from sklearn import linear_model
from sklearn.linear_model import Ridge

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Read in CSV

sample_df = pd.read_csv('data/US_FIN_BALANCE_SHEET_STATEMENT_sample.csv', parse_dates=['end_date']).\
            drop(columns=['start_date', 'months', 'timedepositsplaced'])


sample_df.shape
sample_df.head(10)
sample_df.dtypes
# Out:
# (999, 55)
#    company_cik primary_security_ticker   end_date  fiscal_year fiscal_period  \
# 0      1555074                    AAMC 2018-03-31         2018            Q1
# 1      1555074                    AAMC 2017-09-30         2017            Q3
# 2      1555074                    AAMC 2017-06-30         2017            Q2
# 3      1555074                    AAMC 2017-03-31         2017            Q1
# 4      1555074                    AAMC 2017-12-31         2017            FY
# 5      1555074                    AAMC 2016-09-30         2016            Q3
# 6      1555074                    AAMC 2016-06-30         2016            Q2
# 7      1555074                    AAMC 2016-03-31         2016            Q1
# 8      1555074                    AAMC 2016-12-31         2016            FY
# 9      1555074                    AAMC 2015-09-30         2015            Q3
#
#    cashandequivalents  restrictedcash  fedfundssold  \
# 0          29115000.0             NaN           NaN
# 1          32813000.0             NaN           NaN
# 2          31652000.0             NaN           NaN
# 3          30855000.0             NaN           NaN
# 4          33349000.0             NaN           NaN
# 5          41893000.0             0.0           NaN
# 6          39419000.0             0.0           NaN
# 7          41646000.0             0.0           NaN
# 8          40584000.0             NaN           NaN
# 9         152634000.0      25511000.0           NaN
#
#    interestbearingdepositsatotherbanks  tradingaccountsecurities  \
# 0                                  NaN                       NaN
# 1                                  NaN                18048000.0
# 2                                  NaN                21021000.0
# 3                                  NaN                24773000.0
# 4                                  NaN                       NaN
# 5                                  NaN                17707000.0
# 6                                  NaN                14929000.0
# 7                                  NaN                19494000.0
# 8                                  NaN                17934000.0
# 9                                  NaN                       NaN
#
#              ...              commonequity  retainedearnings  treasurystock  \
# 0            ...                39053000.0        33225000.0   -272524000.0
# 1            ...                36527000.0        40805000.0   -272014000.0
# 2            ...                34861000.0        42982000.0   -272014000.0
# 3            ...                32958000.0        44775000.0   -270480000.0
# 4            ...                37793000.0        38970000.0   -272328000.0
# 5            ...                28311000.0        47860000.0   -262304000.0
# 6            ...                25877000.0        48982000.0   -261575000.0
# 7            ...                23489000.0        50295000.0   -257319000.0
# 8            ...                30722000.0        46145000.0   -266484000.0
# 9            ...                21002000.0        59670000.0   -252072000.0
#
#         aoci  otherequity  totalcommonequity  totalequity  \
# 0        0.0          NaN       -200246000.0 -200246000.0
# 1 -2548000.0          NaN       -197230000.0 -197230000.0
# 2   261000.0          NaN       -193910000.0 -193910000.0
# 3  2569000.0          NaN       -190178000.0 -190178000.0
# 4 -1330000.0          NaN       -196895000.0 -196895000.0
# 5 -2889000.0          NaN       -189022000.0 -189022000.0
# 6 -5667000.0          NaN       -192383000.0 -192383000.0
# 7 -1102000.0          NaN       -184637000.0 -184637000.0
# 8 -2662000.0          NaN       -192279000.0 -192279000.0
# 9        NaN          NaN       -171400000.0 -171400000.0
#
#    noncontrollinginterests  totalequityandnoncontrollinginterests  \
# 0                      NaN                          -2.002460e+08
# 1                      NaN                          -1.972300e+08
# 2                      NaN                          -1.939100e+08
# 3                      NaN                          -1.901780e+08
# 4                      NaN                          -1.968950e+08
# 5             0.000000e+00                          -1.890220e+08
# 6             0.000000e+00                          -1.923830e+08
# 7             0.000000e+00                          -1.846370e+08
# 8                      NaN                          -1.922790e+08
# 9             1.221907e+09                           1.050507e+09
#
#    totalliabilitiesandequity
# 0               5.286700e+07
# 1               5.870900e+07
# 2               6.046300e+07
# 3               6.322900e+07
# 4               6.038700e+07
# 5               6.594100e+07
# 6               6.121600e+07
# 7               6.813500e+07
# 8               6.574800e+07
# 9               2.810701e+09
#
# [10 rows x 55 columns]
# company_cik                                       int64
# primary_security_ticker                          object
# end_date                                 datetime64[ns]
# fiscal_year                                       int64
# fiscal_period                                    object
# cashandequivalents                              float64
# restrictedcash                                  float64
# fedfundssold                                    float64
# interestbearingdepositsatotherbanks             float64
# tradingaccountsecurities                        float64
# loansandleases                                  float64
# allowanceforloanandleaselosses                  float64
# netloansandleases                               float64
# loansheldforsale                                float64
# accruedinvestmentincome                         float64
# customerandotherreceivables                     float64
# netpremisesandequipment                         float64
# mortgageservicingrights                         float64
# unearnedpremiumsdebit                           float64
# deferredacquisitioncost                         float64
# separateaccountbusinessassets                   float64
# goodwill                                        float64
# intangibleassets                                float64
# otherassets                                     float64
# totalassets                                     float64
# noninterestbearingdeposits                      float64
# interestbearingdeposits                         float64
# fedfundspurchased                               float64
# shorttermdebt                                   float64
# bankersacceptances                              float64
# accruedinterestpayable                          float64
# othershorttermpayables                          float64
# longtermdebt                                    float64
# capitalleaseobligations                         float64
# claimsandclaimexpenses                          float64
# futurepolicybenefits                            float64
# unearnedpremiumscredit                          float64
# policyholderfunds                               float64
# participatingpolicyholderequity                 float64
# separateaccountbusinessliabilities              float64
# otherlongtermliabilities                        float64
# totalliabilities                                float64
# commitmentsandcontingencies                     float64
# redeemablenoncontrollinginterest                float64
# totalpreferredequity                            float64
# commonequity                                    float64
# retainedearnings                                float64
# treasurystock                                   float64
# aoci                                            float64
# otherequity                                     float64
# totalcommonequity                               float64
# totalequity                                     float64
# noncontrollinginterests                         float64
# totalequityandnoncontrollinginterests           float64
# totalliabilitiesandequity                       float64
# dtype: object

# %%
# Trim to columns of major interest
# Keep only FY period
# Drop 2017 rows so can calc a c. 2 year return

sample_trimmed = sample_df[['primary_security_ticker','end_date', 'fiscal_year', 'fiscal_period', 'retainedearnings', \
                            'totalassets', 'cashandequivalents', 'longtermdebt', 'shorttermdebt', 'totalliabilities']].\
                loc[(sample_df['fiscal_period'] == 'FY') & (sample_df['fiscal_year'] != 2017)]

sample_trimmed.shape
sample_trimmed.head(10)
# Out:
# (241, 10)
#    primary_security_ticker   end_date  fiscal_year fiscal_period  \
# 8                     AAMC 2016-12-31         2016            FY
# 12                    AAMC 2015-12-31         2015            FY
# 16                    AAMC 2014-12-31         2014            FY
# 20                    AAMC 2013-12-31         2013            FY
# 21                    AAMC 2012-12-31         2012            FY
# 30                    AAME 2016-12-31         2016            FY
# 34                    AAME 2015-12-31         2015            FY
# 38                    AAME 2014-12-31         2014            FY
# 42                    AAME 2013-12-31         2013            FY
# 46                    AAME 2012-12-31         2012            FY
#
#     retainedearnings   totalassets  cashandequivalents  longtermdebt  \
# 8         46145000.0  6.574800e+07          40584000.0           NaN
# 12        50678000.0  2.518601e+09         184544000.0  1.265968e+09
# 16        54174000.0  2.760698e+09         116782000.0  1.345251e+09
# 20        -5339000.0  1.405104e+09         140000000.0  6.052650e+08
# 21          -46000.0  1.058150e+08         105014000.0  5.280000e+05
# 30        27272000.0  3.186000e+08          13252000.0  3.373800e+07
# 34        25443000.0  3.146030e+08          15622000.0  3.373800e+07
# 38        21866000.0  3.170080e+08          16375000.0  3.373800e+07
# 42        18738000.0  3.193810e+08          33102000.0  4.123800e+07
# 46         8621000.0  3.201770e+08          18951000.0  4.123800e+07
#
#     shorttermdebt  totalliabilities
# 8             NaN      8.687000e+06
# 12            NaN      1.304690e+09
# 16            NaN      1.361977e+09
# 20            NaN      6.121370e+08
# 21            NaN      9.340000e+05
# 30            NaN      2.130940e+08
# 34            NaN      2.121110e+08
# 38            NaN      2.128130e+08
# 42            NaN      2.184540e+08
# 46            NaN      2.144410e+08

# %%
# Unstack columns by fiscal_year

sample_T = sample_trimmed.drop(columns=['fiscal_period', 'end_date']).set_index(['primary_security_ticker', 'fiscal_year']).\
            unstack(level=-1)

sample_T.shape
sample_T.head(10)
# Out:
# (36, 54)
#                         retainedearnings                            \
# fiscal_year                         2008         2009         2010
# primary_security_ticker
# AAMC                                 NaN          NaN          NaN
# AAME                                 NaN          NaN    3886000.0
# AAT                                  NaN          NaN          NaN
# AB                                   NaN          NaN          NaN
# ABCB                                 NaN          NaN   37000000.0
# ABCW                                 NaN          NaN -103362000.0
# ABR                                  NaN          NaN -180689667.0
# AC                                   NaN          NaN          NaN
# ACC                                  NaN -189165000.0 -249381000.0
# ACFC                                 NaN          NaN    2581000.0
#
#                                                                              \
# fiscal_year                     2011         2012         2013         2014
# primary_security_ticker
# AAMC                             NaN     -46000.0   -5339000.0   54174000.0
# AAME                       6179000.0    8621000.0   18738000.0   21866000.0
# AAT                      -28007000.0  -25625000.0  -44090000.0  -60291000.0
# AB                               NaN          NaN          NaN          NaN
# ABCB                      54852000.0   65710000.0   83991000.0  118412000.0
# ABCW                    -147513000.0 -189097000.0   20359000.0   34981000.0
# ABR                     -221015880.0 -207558257.0 -212231319.0 -152483322.0
# AC                               NaN          NaN          NaN          0.0
# ACC                     -286565000.0 -347521000.0 -392338000.0 -487986000.0
# ACFC                      -7706000.0  -14373000.0  -25779000.0  -24452000.0
#
#                                                   totalassets      ...       \
# fiscal_year                     2015         2016        2008      ...
# primary_security_ticker                                            ...
# AAMC                      50678000.0   46145000.0         NaN      ...
# AAME                      25443000.0   27272000.0         NaN      ...
# AAT                      -64066000.0  -77296000.0         NaN      ...
# AB                               NaN          NaN         NaN      ...
# ABCB                     152820000.0  214454000.0         NaN      ...
# ABCW                     172610000.0          NaN         NaN      ...
# ABR                     -136118001.0 -125134000.0         NaN      ...
# AC                         2072000.0    7327000.0         NaN      ...
# ACC                     -550501000.0 -670137000.0         NaN      ...
# ACFC                     -16734000.0  -10316000.0         NaN      ...
#
#                         shorttermdebt totalliabilities                \
# fiscal_year                      2016             2008          2009
# primary_security_ticker
# AAMC                              NaN              NaN           NaN
# AAME                              NaN              NaN           NaN
# AAT                        20000000.0              NaN           NaN
# AB                                NaN              NaN  2.183000e+06
# ABCB                       53505000.0              NaN           NaN
# ABCW                              NaN              NaN           NaN
# ABR                               NaN              NaN           NaN
# AC                          2396000.0              NaN           NaN
# ACC                               NaN              NaN  1.295485e+09
# ACFC                              NaN              NaN           NaN
#
#                                                                    \
# fiscal_year                      2010          2011          2012
# primary_security_ticker
# AAMC                              NaN           NaN  9.340000e+05
# AAME                     1.948730e+08  2.058480e+08  2.144410e+08
# AAT                      9.622360e+08  1.029553e+09  1.141858e+09
# AB                       4.580000e+05  2.811000e+06  6.411000e+06
# ABCB                     2.698761e+09  2.700537e+09  2.740035e+09
# ABCW                     3.407996e+09  2.819002e+09  2.427447e+09
# ABR                      1.524793e+09  1.603654e+09  1.470620e+09
# AC                                NaN           NaN           NaN
# ACC                      1.440885e+09  1.562254e+09  2.384374e+09
# ACFC                     7.826510e+08  7.426730e+08  7.323590e+08
#
#                                                                    \
# fiscal_year                      2013          2014          2015
# primary_security_ticker
# AAMC                     6.121370e+08  1.361977e+09  1.304690e+09
# AAME                     2.184540e+08  2.128130e+08  2.121110e+08
# AAT                      1.145865e+09  1.175186e+09  1.145362e+09
# AB                       7.760000e+05  3.820000e+05  2.740000e+05
# ABCB                     3.350950e+09  3.671049e+09  5.074181e+09
# ABCW                     1.910276e+09  1.854716e+09  1.881857e+09
# ABR                      1.439876e+09  1.331039e+09  1.262301e+09
# AC                                NaN  1.034330e+08  7.946100e+07
# ACC                      2.919511e+09  3.164993e+09  3.165080e+09
# ACFC                     6.681080e+08  6.341620e+08  7.764600e+08
#
#
# fiscal_year                      2016
# primary_security_ticker
# AAMC                     8.687000e+06
# AAME                     2.130940e+08
# AAT                      1.148382e+09
# AB                       6.190000e+05
# ABCB                     6.245594e+09
# ABCW                              NaN
# ABR                      2.223748e+09
# AC                       7.435100e+07
# ACC                      2.360348e+09
# ACFC                     8.204410e+08
#
# [10 rows x 54 columns]

# %%
# Get column names

list(sample_T.columns.values)
# Out:
# [('retainedearnings', 2008),
#  ('retainedearnings', 2009),
#  ('retainedearnings', 2010),
#  ('retainedearnings', 2011),
#  ('retainedearnings', 2012),
#  ('retainedearnings', 2013),
#  ('retainedearnings', 2014),
#  ('retainedearnings', 2015),
#  ('retainedearnings', 2016),
#  ('totalassets', 2008),
#  ('totalassets', 2009),
#  ('totalassets', 2010),
#  ('totalassets', 2011),
#  ('totalassets', 2012),
#  ('totalassets', 2013),
#  ('totalassets', 2014),
#  ('totalassets', 2015),
#  ('totalassets', 2016),
#  ('cashandequivalents', 2008),
#  ('cashandequivalents', 2009),
#  ('cashandequivalents', 2010),
#  ('cashandequivalents', 2011),
#  ('cashandequivalents', 2012),
#  ('cashandequivalents', 2013),
#  ('cashandequivalents', 2014),
#  ('cashandequivalents', 2015),
#  ('cashandequivalents', 2016),
#  ('longtermdebt', 2008),
#  ('longtermdebt', 2009),
#  ('longtermdebt', 2010),
#  ('longtermdebt', 2011),
#  ('longtermdebt', 2012),
#  ('longtermdebt', 2013),
#  ('longtermdebt', 2014),
#  ('longtermdebt', 2015),
#  ('longtermdebt', 2016),
#  ('shorttermdebt', 2008),
#  ('shorttermdebt', 2009),
#  ('shorttermdebt', 2010),
#  ('shorttermdebt', 2011),
#  ('shorttermdebt', 2012),
#  ('shorttermdebt', 2013),
#  ('shorttermdebt', 2014),
#  ('shorttermdebt', 2015),
#  ('shorttermdebt', 2016),
#  ('totalliabilities', 2008),
#  ('totalliabilities', 2009),
#  ('totalliabilities', 2010),
#  ('totalliabilities', 2011),
#  ('totalliabilities', 2012),
#  ('totalliabilities', 2013),
#  ('totalliabilities', 2014),
#  ('totalliabilities', 2015),
#  ('totalliabilities', 2016)]

# %%
# Calculate ratios and changes in ratios for 1 year, 2 year and 3 year changes

sample_T[('retainedearnings', 'change_1Y')] = sample_T[('retainedearnings', 2016)] / sample_T[('retainedearnings', 2015)]
sample_T[('retainedearnings', 'change_2Y')] = sample_T[('retainedearnings', 2016)] / sample_T[('retainedearnings', 2014)]
sample_T[('retainedearnings', 'change_3Y')] = sample_T[('retainedearnings', 2016)] / sample_T[('retainedearnings', 2013)]

sample_T[('totalassets', 'change_1Y')] = sample_T[('totalassets', 2016)] / sample_T[('totalassets', 2015)]
sample_T[('totalassets', 'change_2Y')] = sample_T[('totalassets', 2016)] / sample_T[('totalassets', 2014)]
sample_T[('totalassets', 'change_3Y')] = sample_T[('totalassets', 2016)] / sample_T[('totalassets', 2013)]

sample_T[('cashandequivalents', 'change_1Y')] = sample_T[('cashandequivalents', 2016)] / sample_T[('cashandequivalents', 2015)]
sample_T[('cashandequivalents', 'change_2Y')] = sample_T[('cashandequivalents', 2016)] / sample_T[('cashandequivalents', 2014)]
sample_T[('cashandequivalents', 'change_3Y')] = sample_T[('cashandequivalents', 2016)] / sample_T[('cashandequivalents', 2013)]

sample_T[('longtermdebt', 'change_1Y')] = sample_T[('longtermdebt', 2016)] / sample_T[('longtermdebt', 2015)]
sample_T[('longtermdebt', 'change_2Y')] = sample_T[('longtermdebt', 2016)] / sample_T[('longtermdebt', 2014)]
sample_T[('longtermdebt', 'change_3Y')] = sample_T[('longtermdebt', 2016)] / sample_T[('longtermdebt', 2013)]

sample_T[('shorttermdebt', 'change_1Y')] = sample_T[('shorttermdebt', 2016)] / sample_T[('shorttermdebt', 2015)]
sample_T[('shorttermdebt', 'change_2Y')] = sample_T[('shorttermdebt', 2016)] / sample_T[('shorttermdebt', 2014)]
sample_T[('shorttermdebt', 'change_3Y')] = sample_T[('shorttermdebt', 2016)] / sample_T[('shorttermdebt', 2013)]

sample_T[('totalliabilities', 'change_1Y')] = sample_T[('totalliabilities', 2016)] / sample_T[('totalliabilities', 2015)]
sample_T[('totalliabilities', 'change_2Y')] = sample_T[('totalliabilities', 2016)] / sample_T[('totalliabilities', 2014)]
sample_T[('totalliabilities', 'change_3Y')] = sample_T[('totalliabilities', 2016)] / sample_T[('totalliabilities', 2013)]



sample_T.shape
# list(sample_T.columns.values)
# sample_T[[('retainedearnings', 2015), ('retainedearnings', 2016), ('retainedearnings', 'change_1Y')]].head()
sample_T[[('retainedearnings', 'change_1Y'), ('retainedearnings', 'change_2Y'), ('retainedearnings', 'change_3Y'),\
          ('totalassets', 'change_1Y'), ('totalassets', 'change_2Y'), ('totalassets', 'change_3Y'),\
          ('cashandequivalents', 'change_1Y'), ('cashandequivalents', 'change_2Y'), ('cashandequivalents', 'change_3Y'),\
          ('longtermdebt', 'change_1Y'), ('longtermdebt', 'change_2Y'), ('longtermdebt', 'change_3Y'),\
          ('shorttermdebt', 'change_1Y'), ('shorttermdebt', 'change_2Y'), ('shorttermdebt', 'change_3Y'),\
          ('totalliabilities', 'change_1Y'), ('totalliabilities', 'change_2Y'), ('totalliabilities', 'change_3Y'),\
         ]].head(10)
# Out:
# (36, 72)
#                         retainedearnings                     totalassets  \
# fiscal_year                    change_1Y change_2Y change_3Y   change_1Y
# primary_security_ticker
# AAMC                            0.910553  0.851792 -8.643004    0.026105
# AAME                            1.071886  1.247233  1.455438    1.012705
# AAT                             1.206506  1.282049  1.753141    1.006404
# AB                                   NaN       NaN       NaN    0.977405
# ABCB                            1.403311  1.811083  2.553297    1.233155
# ABCW                                 NaN       NaN       NaN         NaN
# ABR                             0.919305  0.820641  0.589611    1.625697
# AC                              3.536197       inf       NaN    1.138459
# ACC                             1.217322  1.373271  1.708060    0.976635
# ACFC                            0.616469  0.421888  0.400171    1.058634
#
#                                             cashandequivalents            \
# fiscal_year             change_2Y change_3Y          change_1Y change_2Y
# primary_security_ticker
# AAMC                     0.023816  0.046792           0.219915  0.347519
# AAME                     1.005022  0.997555           0.848291  0.809282
# AAT                      1.023263  1.084308           1.122129  0.754772
# AB                       0.946321  1.004469                NaN       NaN
# ABCB                     1.707183  1.879141           1.072951  1.629556
# ABCW                          NaN       NaN                NaN       NaN
# ABR                      1.591640  1.582333           0.734704  2.749925
# AC                       1.262237       NaN           1.526576  1.100035
# ACC                      1.005341  1.047851           1.329011  0.883409
# ACFC                     1.284447  1.236939           0.612967  1.258911
#
#                                   longtermdebt                      \
# fiscal_year             change_3Y    change_1Y change_2Y change_3Y
# primary_security_ticker
# AAMC                     0.289886          NaN       NaN       NaN
# AAME                     0.400338     1.000000  1.000000  0.818129
# AAT                      0.914549     1.015519  0.979977  1.093844
# AB                            NaN          NaN       NaN       NaN
# ABCB                     2.019919     5.295562  3.998093  2.305846
# ABCW                          NaN          NaN       NaN       NaN
# ABR                      2.295844     1.764790  1.663053  1.637245
# AC                            NaN          NaN       NaN       NaN
# ACC                      0.571340     0.720860  0.714934  0.799995
# ACFC                     1.295950     0.909489  1.526341  1.715982
#
#                         shorttermdebt                     totalliabilities  \
# fiscal_year                 change_1Y change_2Y change_3Y        change_1Y
# primary_security_ticker
# AAMC                              NaN       NaN       NaN         0.006658
# AAME                              NaN       NaN       NaN         1.004634
# AAT                          0.666667       inf  0.215054         1.002637
# AB                                NaN       NaN       NaN         2.259124
# ABCB                         0.841472  0.729846  0.640656         1.230858
# ABCW                              NaN       NaN       NaN              NaN
# ABR                               NaN       NaN       NaN         1.761662
# AC                           0.047307  0.055211       NaN         0.935692
# ACC                               NaN       NaN       NaN         0.745747
# ACFC                              NaN       NaN       NaN         1.056643
#
#
# fiscal_year             change_2Y change_3Y
# primary_security_ticker
# AAMC                     0.006378  0.014191
# AAME                     1.001320  0.975464
# AAT                      0.977192  1.002197
# AB                       1.620419  0.797680
# ABCB                     1.701310  1.863828
# ABCW                          NaN       NaN
# ABR                      1.670686  1.544402
# AC                       0.718832       NaN
# ACC                      0.745767  0.808474
# ACFC                     1.293740  1.228007

# %%
# Get price changes, from end of 2016 to latest in 2018
### *** PICK UP HERE *** ###

# %%
# Build Ridge regression model

predictors = [('retainedearnings', 'change_1Y'), ('retainedearnings', 'change_2Y'), ('retainedearnings', 'change_3Y'),\
          ('totalassets', 'change_1Y'), ('totalassets', 'change_2Y'), ('totalassets', 'change_3Y'),\
          ('cashandequivalents', 'change_1Y'), ('cashandequivalents', 'change_2Y'), ('cashandequivalents', 'change_3Y'),\
          ('longtermdebt', 'change_1Y'), ('longtermdebt', 'change_2Y'), ('longtermdebt', 'change_3Y'),\
          ('shorttermdebt', 'change_1Y'), ('shorttermdebt', 'change_2Y'), ('shorttermdebt', 'change_3Y'),\
          ('totalliabilities', 'change_1Y'), ('totalliabilities', 'change_2Y'), ('totalliabilities', 'change_3Y'),\
         ]

ridgereg = Ridge(alpha=alpha,normalize=True)
ridgereg.fit(data[predictors],data['y'])

# %% [markdown]
# ## Scrap code

# %%
ls data
# Out:
# US_FIN_BALANCE_SHEET_STATEMENT_sample.csv*
